# %%
# %load_ext autoreload
# %autoreload 2

import torch

# from confusions import evaluate_and_report
# from data import load_mnist_normalized, split_train_dev_test, make_dataloaders
# from model import HyperParams, DNN
# from train_eval import train_model, evaluate_model
# from plots import plot_example_digits, plot_learning_curves
# from mnist_activations import visualize_activations_on_loader, visualize_activations_by_label
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# confusions.py

import torch
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

def evaluate_and_report(model, dataloader, device="cpu", class_names=None):
    """
    model: trained PyTorch model
    dataloader: test DataLoader
    class_names: list of names for sklearn display (optional)
    """
    model.eval()
    model.to(device)

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for xb, yb in dataloader:
            xb = xb.to(device).float()
            yb = yb.to(device).long()

            logits = model(xb)
            preds = torch.argmax(logits, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(yb.cpu().numpy())

    # ---- Classification Report ----
    print("\nCLASSIFICATION REPORT\n")
    print(classification_report(all_labels, all_preds,
                                digits=5,
                                target_names=class_names))

    # ---- Confusion Matrix ----
    cm = confusion_matrix(all_labels, all_preds)

    plt.figure(figsize=(8, 8))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=class_names)
    disp.plot(cmap="Blues", values_format="d")
    plt.xticks(rotation=45)
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()

    return None

# %%
# data.py

from sklearn.datasets import fetch_openml
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
from torch.utils.data import Dataset, DataLoader


class MNISTDataset(Dataset):
    """Wraps numpy arrays as a PyTorch Dataset."""

    def __init__(self, input_data: np.ndarray, labels: np.ndarray):
        self.feats = input_data
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, index):
        X = self.feats[index]
        y = self.labels[index]
        return X, y


def load_mnist_normalized():
    """
    Load MNIST via fetch_openml and normalize to roughly [-1, 1].
    Returns X, y as numpy arrays.
    """
    mnist = fetch_openml("mnist_784", version=1)
    X, y = mnist["data"], mnist["target"]
    y = y.astype(int)

    # Your scaling: ((X / 255) - 0.5) * 2
    X = ((X / 255.0) - 0.5) * 2.0
    
    X_reshaped = X.to_numpy().reshape(-1, 1, 28, 28)

    return X_reshaped, y.to_numpy()


def split_train_dev_test(X, y, train_size=60000, random_state=12):
    """
    First 60k -> train+dev, last 10k -> test (as in original notebook).
    Then stratified split train->(train, dev).
    """
    X_train_full, X_test = X[:train_size], X[train_size:]
    y_train_full, y_test = y[:train_size], y[train_size:]

    splitter = StratifiedShuffleSplit(
        n_splits=1, test_size=0.1, random_state=random_state
    )
    (train_idx, dev_idx), = splitter.split(X_train_full, y_train_full)

    X_train, y_train = X_train_full[train_idx], y_train_full[train_idx]
    X_dev, y_dev = X_train_full[dev_idx], y_train_full[dev_idx]

    return (X_train, y_train), (X_dev, y_dev), (X_test, y_test)


def make_dataloaders(
    X_train,
    y_train,
    X_dev,
    y_dev,
    X_test,
    y_test,
    batch_size=64,
    test_batch_size=16,
):
    """Create PyTorch DataLoaders from numpy arrays."""
    train_set = MNISTDataset(X_train, y_train)
    dev_set = MNISTDataset(X_dev, y_dev)
    test_set = MNISTDataset(X_test, y_test)

    train_loader = DataLoader(
        train_set,
        batch_size=batch_size,
        shuffle=True,
        num_workers=0,
        drop_last=False,
        pin_memory=False,
    )

    dev_loader = DataLoader(
        dev_set,
        batch_size=batch_size,
        shuffle=True,
        num_workers=0,
        drop_last=False,
        pin_memory=False,
    )

    test_loader = DataLoader(
        test_set,
        batch_size=test_batch_size,
        shuffle=False,
        num_workers=0,
        drop_last=False,
        pin_memory=False,
    )

    return train_loader, dev_loader, test_loader

# %%
# mnist_activations.py

"""
Activation-visualization helpers for the MNIST DNN example.

Typical usage from a notebook:

    from mnist_activations import (
        visualize_activations_on_loader,
        visualize_activations_by_label,
    )

    # Simple, whole-batch activations:
    visualize_activations_on_loader(model, dev_gen)

    # Conditional on digit identity (true label):
    visualize_activations_by_label(model, dev_gen, max_batches=3)

"""

from typing import Dict, List, Optional

import math
import torch
import matplotlib.pyplot as plt

def visualize_kernels(model, layer_name: str, num_kernels: int | None = None, cmap: str = "gray"):
    """
    Visualize the kernels of a given Conv2d layer in the model.

    Args:
        model: your CNN model (with attributes like model.conv1, model.conv2)
        layer_name: name of the convolutional layer to visualize ("conv1", "conv2", ...)
        num_kernels: how many output kernels/filters to show (None = all)
        cmap: colormap for imshow
    """
    # Get the layer by name
    layer = getattr(model, layer_name, None)
    if layer is None:
        print(f"Layer '{layer_name}' not found in the model.")
        return

    if not isinstance(layer, torch.nn.Conv2d):
        print(f"Layer '{layer_name}' is not a Conv2d layer.")
        return

    # Extract weights: (out_channels, in_channels, kH, kW)
    kernels = layer.weight.detach().cpu().numpy()
    out_channels, in_channels, kH, kW = kernels.shape

    # Decide how many kernels to show
    if num_kernels is None or num_kernels > out_channels:
        num_kernels = out_channels

    # One row, num_kernels columns (this matches what you were doing)
    fig, axes = plt.subplots(1, num_kernels, figsize=(num_kernels * 2, 2))
    if num_kernels == 1:
        axes = [axes]

    for i in range(num_kernels):
        ax = axes[i]
        # Take the first input channel of each kernel
        kernel_2d = kernels[i, 0, :, :]  # shape: (kH, kW)
        ax.imshow(kernel_2d, cmap=cmap)
        ax.axis("off")
        ax.set_title(f"{layer_name}[{i}]")

    plt.suptitle(f"Kernels from {layer_name}", y=1.02)
    plt.tight_layout()
    plt.show()



# ---------- Core hook + batch capture ----------


def _register_fc_hooks(
    model: torch.nn.Module,
    activations: Dict[str, torch.Tensor],
) -> List[torch.utils.hooks.RemovableHandle]:
    """Register forward hooks on layers named fc1, fc2, fc3 if present."""
    handles: List[torch.utils.hooks.RemovableHandle] = []

    for name in ["fc1", "fc2", "fc3"]:
        layer = getattr(model, name, None)
        if layer is None:
            continue

        def _make_hook(layer_name: str):
            def hook(module, inp, out):
                # Save a detached CPU copy; shape ~ (batch_size, hidden_units)
                activations[layer_name] = out.detach().cpu()

            return hook

        handles.append(layer.register_forward_hook(_make_hook(name)))

    return handles


def collect_activations_on_batch(
    model: torch.nn.Module,
    batch: torch.Tensor,
    device: Optional[str] = None,
) -> Dict[str, torch.Tensor]:
    """Run a single batch through the model and collect activations."""
    if device is None:
        device = "cuda" if torch.cuda.is_available() else "cpu"

    model.to(device)
    model.eval()

    activations: Dict[str, torch.Tensor] = {}
    handles = _register_fc_hooks(model, activations)

    with torch.no_grad():
        batch = batch.float().to(device)
        _ = model(batch)

    # Remove hooks to avoid side-effects for later calls
    for h in handles:
        h.remove()

    return activations


# ---------- Simple global plots ----------


def _plot_histograms(activations: Dict[str, torch.Tensor]) -> None:
    """For each layer, plot a histogram of all activation values."""
    num_layers = len(activations)
    if num_layers == 0:
        print("No activations captured.")
        return

    fig, axes = plt.subplots(1, num_layers, figsize=(5 * num_layers, 4))
    if num_layers == 1:
        axes = [axes]

    for ax, (layer_name, act) in zip(axes, activations.items()):
        flat = act.flatten().numpy()
        ax.hist(flat, bins=50)
        ax.set_title(f"{layer_name} activations")
        ax.set_xlabel("Value")
        ax.set_ylabel("Frequency")

    fig.tight_layout()
    plt.show()


def _plot_heatmaps(
    activations: Dict[str, torch.Tensor],
    max_neurons: int = 64,
) -> None:
    """Show a coarse heatmap of activations for the first few neurons per layer."""
    num_layers = len(activations)
    if num_layers == 0:
        return

    fig, axes = plt.subplots(num_layers, 1, figsize=(8, 3 * num_layers))
    if num_layers == 1:
        axes = [axes]

    for ax, (layer_name, act) in zip(axes, activations.items()):
        # act shape: (batch_size, num_units)
        batch_size, num_units = act.shape[:2]
        keep = min(num_units, max_neurons)
        sub = act[:, :keep].numpy()  # (batch_size, keep)

        im = ax.imshow(sub, aspect="auto", interpolation="nearest")
        ax.set_title(f"{layer_name} (first {keep} units across batch)")
        ax.set_xlabel("Unit index")
        ax.set_ylabel("Batch index")
        plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

    fig.tight_layout()
    plt.show()


def visualize_activations_on_loader(
    model: torch.nn.Module,
    loader,
    device: Optional[str] = None,
    max_batches: int = 1,
) -> None:
    """
    Grab up to `max_batches` from `loader` and visualize activations (global).

    This is the original "whole batch" view:
      * one histogram per layer
      * one heatmap per layer
    """
    # Take a few batches and concatenate them
    batches = []
    for i, (xb, yb) in enumerate(loader):
        batches.append(xb)
        if i + 1 >= max_batches:
            break

    batch = torch.cat(batches, dim=0)
    activations = collect_activations_on_batch(model, batch, device=device)

    print("Layers captured:", list(activations.keys()))
    _plot_histograms(activations)
    _plot_heatmaps(activations)


# ---------- NEW: label-conditional heatmaps ----------


def _plot_label_heatmaps(
    activations: Dict[str, torch.Tensor],
    labels: torch.Tensor,
    max_neurons: int = 64,
    num_classes: int = 10,
    min_per_class: int = 1,
) -> None:
    """
    For each layer, make a grid of heatmaps, one per digit (0..9 by default).

    Each heatmap has:
      * rows = examples of that digit (from the sampled batches)
      * columns = first `max_neurons` units in that layer

    This uses the *true labels* (correct digit identity) for conditioning.
    """
    if len(activations) == 0:
        print("No activations captured.")
        return

    labels_np = labels.cpu().numpy()

    # Decide which classes to show: those in [0, num_classes) with enough examples
    present_classes = []
    for c in range(num_classes):
        count_c = (labels_np == c).sum()
        if count_c >= min_per_class:
            present_classes.append(c)

    if not present_classes:
        print("No classes with at least", min_per_class, "examples.")
        return

    # Build a grid for the classes (axes grid)
    n_classes = len(present_classes)
    ncols = min(5, n_classes)
    nrows = math.ceil(n_classes / ncols)

    for layer_name, act in activations.items():
        # act has shape (N, num_units)
        num_units = act.shape[1]
        keep = min(num_units, max_neurons)

        fig, axes = plt.subplots(
            nrows=nrows,
            ncols=ncols,
            figsize=(3 * ncols, 2.5 * nrows),
            squeeze=False,
        )

        for idx, digit in enumerate(present_classes):
            r, c = divmod(idx, ncols)
            ax = axes[r][c]

            mask = labels_np == digit
            sub = act[mask, :keep].numpy()  # shape: (num_examples_of_digit, keep)

            if sub.size == 0:
                ax.axis("off")
                continue

            im = ax.imshow(sub, aspect="auto", interpolation="nearest")
            ax.set_title(f"digit = {digit}")
            ax.set_xlabel("unit")
            ax.set_ylabel("example")
            fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

        # Hide any unused axes
        for j in range(n_classes, nrows * ncols):
            r, c = divmod(j, ncols)
            axes[r][c].axis("off")

        fig.suptitle(f"Activations in {layer_name} by digit", y=1.02)
        fig.tight_layout()
        plt.show()


def visualize_activations_by_label(
    model: torch.nn.Module,
    loader,
    device: Optional[str] = None,
    max_batches: int = 3,
    max_neurons: int = 32,
    num_classes: int = 10,
    min_per_class: int = 1,
) -> None:
    """
    Sort a few batches by digit identity and show layer activations per digit.

    Steps:
      1. Take up to `max_batches` from the DataLoader.
      2. Concatenate them into one big batch (X, y).
      3. Run the entire batch through `model` and collect activations
         from fc1, fc2, fc3.
      4. For each layer, make a grid of heatmaps, one per digit.

    The conditioning is on the *true labels* `y`.

    Args:
        model: trained DNN model.
        loader: DataLoader that yields (images, labels).
        device: torch device string or None for auto-select.
        max_batches: how many batches to pull from the loader.
        max_neurons: how many units to display per layer (columns).
        num_classes: how many distinct labels (e.g., 10 for digits 0–9).
        min_per_class: minimum examples required to show a digit.
    """
    # Collect a few batches
    xs, ys = [], []
    for i, (xb, yb) in enumerate(loader):
        xs.append(xb)
        ys.append(yb)
        if i + 1 >= max_batches:
            break

    if not xs:
        print("Loader appears to be empty.")
        return

    X = torch.cat(xs, dim=0)
    y = torch.cat(ys, dim=0)

    activations = collect_activations_on_batch(model, X, device=device)

    print("Layers captured:", list(activations.keys()))
    print("Total examples sampled:", X.shape[0])
    _plot_label_heatmaps(
        activations,
        y,
        max_neurons=max_neurons,
        num_classes=num_classes,
        min_per_class=min_per_class,
    )

# %%
# model.py

import torch
import torch.nn as nn
import torch.nn.functional as F
from dataclasses import dataclass


@dataclass
class HyperParams:
    num_classes: int = 10
    lr: float = 0.05
    num_epochs: int = 100
    batch_size: int = 50
    

class CNN(nn.Module):
    def __init__(self, config: HyperParams, dropout_rate: float):
        super().__init__()
        self.config = config

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=3, stride=1, padding=1)
        self.dropout1 = nn.Dropout2d(p=dropout_rate)
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=10, kernel_size=3, stride=1, padding=1)
        self.dropout2 = nn.Dropout2d(p=dropout_rate)
        self.fc    = nn.Linear(10 * 28 * 28, config.num_classes)
        
        nn.init.xavier_uniform_(self.conv1.weight)
        nn.init.xavier_uniform_(self.conv2.weight)
        nn.init.xavier_uniform_(self.fc.weight)
        nn.init.zeros_(self.conv1.bias)
        nn.init.zeros_(self.conv2.bias)
        nn.init.zeros_(self.fc.bias)

    def forward(self, x):
        h1 = F.relu(self.conv1(x))
        h1 = self.dropout1(h1)

        h2 = F.relu(self.conv2(h1))
        h2 = self.dropout2(h2) 

        h2_flat = torch.flatten(h2, start_dim=1)
        logits = self.fc(h2_flat)
        return logits

# %%
# plots.py

import matplotlib.pyplot as plt
import numpy as np


def plot_example_digits(X, y, nrows=2, ncols=5):
    """Replicate your sample visualization: one example per digit."""
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, sharey=True)
    ax = ax.flatten()

    for d in range(10):
        idx = np.where(y == d)[0][0]
        img = X[idx].reshape(28, 28)
        ax[d].imshow(img, cmap="Greys")
        ax[d].set_xticks([])
        ax[d].set_yticks([])
        ax[d].set_title(str(d))

    plt.tight_layout()
    plt.show()


def plot_learning_curves(
    tr_losses,
    tr_accs,
    dev_losses,
    dev_accs,
):
    fig, axes = plt.subplots(1, 2, figsize=(10, 4))

    axes[0].plot(tr_losses, label="Train")
    axes[0].plot(dev_losses, label="Dev")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Loss")
    axes[0].set_title("Loss vs Epoch")
    axes[0].grid(True)
    axes[0].legend()

    axes[1].plot(tr_accs, label="Train")
    axes[1].plot(dev_accs, label="Dev")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Accuracy")
    axes[1].set_title("Accuracy vs Epoch")
    axes[1].grid(True)
    axes[1].legend()

    plt.tight_layout()
    plt.show()

# %%
# train_eval.py

import copy
import torch
from torch import nn
from typing import List, Tuple


def train_model(
    model: torch.nn.Module,
    train_loader,
    dev_loader,
    num_epochs: int,
    lr: float,
    device: str = "cpu",
    momentum: float = 0.9,
    step_size: int = 10,
    gamma: float = 0.9,
    patience: int = 10, 
) -> Tuple[
    List[float],
    List[float],
    List[float],
    List[float],
]:
    """
    Train model and return:
    train_losses, train_accuracies, dev_losses, dev_accuracies
    """
    model.to(device)
    optimizer = torch.optim.SGD(
        model.parameters(),
        lr=lr,
        momentum=momentum,
    )
    scheduler = torch.optim.lr_scheduler.StepLR(
        optimizer,
        step_size=step_size,
        gamma=gamma,
    )
    loss_fn = nn.CrossEntropyLoss()

    tr_losses, tr_accs = [], []
    dev_losses, dev_accs = [], []
    
    best_dev_loss = float("inf")
    best_epoch = -1
    epochs_without_improvement = 0
    
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0.0
        num_correct = 0
        num_samples = 0

        for X_batch, y_batch in train_loader:
            X_batch = X_batch.float().to(device)
            y_batch = y_batch.long().to(device)

            optimizer.zero_grad()

            outputs = model(X_batch)
            loss = loss_fn(outputs, y_batch)
            loss.backward()
            optimizer.step()

            total_loss += loss.item() * X_batch.size(0)
            preds = outputs.argmax(dim=1)
            num_correct += (preds == y_batch).sum().item()
            num_samples += X_batch.size(0)

        avg_loss = total_loss / num_samples
        accuracy = num_correct / num_samples

        tr_losses.append(avg_loss)
        tr_accs.append(accuracy)

        dev_loss, dev_acc = evaluate_model(model, dev_loader, loss_fn, device)
        dev_losses.append(dev_loss)
        dev_accs.append(dev_acc)

        print(
            f"Epoch {epoch+1}/{num_epochs} "
            f"- Train loss {avg_loss:.4f}, acc {accuracy:.4f} "
            f"- Dev loss {dev_loss:.4f}, acc {dev_acc:.4f}"
        )
        
        if dev_loss < best_dev_loss:
            best_dev_loss = dev_loss
            best_epoch = epoch
            epochs_without_improvement = 0
        else:
            epochs_without_improvement += 1

        scheduler.step()

        if epochs_without_improvement > patience:
            print(
                f"Early stopping at epoch {epoch+1} "
                f"(no dev-loss improvement for {patience} epochs; "
                f"best epoch was {best_epoch+1}, dev loss {best_dev_loss:.4f})"
            )
            break

    return tr_losses, tr_accs, dev_losses, dev_accs


def evaluate_model(model, data_loader, loss_fn, device="cpu"):
    model.eval()
    total_loss = 0.0
    num_correct = 0
    num_samples = 0

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.float().to(device)
            y_batch = y_batch.long().to(device)

            outputs = model(X_batch)
            loss = loss_fn(outputs, y_batch)

            total_loss += loss.item() * X_batch.size(0)
            preds = outputs.argmax(dim=1)
            num_correct += (preds == y_batch).sum().item()
            num_samples += X_batch.size(0)

    avg_loss = total_loss / num_samples
    accuracy = num_correct / num_samples

    return avg_loss, accuracy

# %% [markdown]
# ## 1. Load and normalize the MNIST data
#
# We:
# 1. Download MNIST via `fetch_openml`
# 2. Scale the pixel values from `[0, 255]` to approximately `[-1, 1]`
# 3. Return the inputs and labels as NumPy arrays.

# %%
X, y = load_mnist_normalized()
print("Data shape:", X.shape)
print("Label shape:", y.shape)
print("Label range:", y.min(), "to", y.max())
# Out:
# Data shape: (70000, 1, 28, 28)
# Label shape: (70000,)
# Label range: 0 to 9

# %% [markdown]
# ## 2. Visualize a few example digits
#
# We plot one example of each digit (0–9) to verify the data looks as expected.

# %%
plot_example_digits(X, y)

# %% [markdown]
# ## 3. Train / dev / test split and DataLoaders
#
# - First, we follow the original dataset's convention: first 60,000 examples for train+dev, last 10,000 for test.
# - Then we perform a stratified split of the training portion into:
#   - a training set (90% of the first 60k)
#   - a dev set (10% of the first 60k)
#
# We need to provide the model configuration now, because the training batch size is needed by the `DataLoader`s that we are going to use to make the data available to PyTorch.
#
#
# Finally, we wrap these arrays in PyTorch `Dataset`s and `DataLoader`s.

# %%
(X_train, y_train), (X_dev, y_dev), (X_test, y_test) = split_train_dev_test(X, y)

config = HyperParams(
    num_classes=10,
    lr=0.05,
    num_epochs=100,
    batch_size=50,
)

train_loader, dev_loader, test_loader = make_dataloaders(
    X_train,
    y_train,
    X_dev,
    y_dev,
    X_test,
    y_test,
    batch_size=config.batch_size,
    test_batch_size=16,
)

print("Train set:", X_train.shape)
print("Dev set:  ", X_dev.shape)
print("Test set: ", X_test.shape)
# Out:
# Train set: (54000, 1, 28, 28)
# Dev set:   (6000, 1, 28, 28)
# Test set:  (10000, 1, 28, 28)

# %% [markdown]
# ## 4. Define the model and training setup
#
# We instantiate:
#
# - a `HyperParams` configuration object
# - the `DNN` model using that configuration
# - the training routine will create an SGD optimizer and CrossEntropy loss.

# %%
device = "cuda" if torch.cuda.is_available() else "mps" if torch.mps.is_available() else "cpu"
print("Using device:", device)

model_025 = CNN(config, dropout_rate=0.25)
model_05 = CNN(config, dropout_rate=0.5)
model_075 = CNN(config, dropout_rate=0.75)
# Out:
# Using device: mps

# %% [markdown]
# ## 5. Train the model
#
# We run the main training loop for `config.num_epochs`, tracking:
#
# - average training loss and accuracy per epoch
# - dev loss and accuracy per epoch

# %%
tr_losses_025, tr_accs_025, dev_losses_025, dev_accs_025 = train_model(
    model=model_025,
    train_loader=train_loader,
    dev_loader=dev_loader,
    num_epochs=config.num_epochs,
    lr=config.lr,
    device=device,
    patience=20,
)
# Out:
# Epoch 1/100 - Train loss 0.3195, acc 0.9094 - Dev loss 0.1166, acc 0.9627
# Epoch 2/100 - Train loss 0.1934, acc 0.9447 - Dev loss 0.0974, acc 0.9707
# Epoch 3/100 - Train loss 0.1706, acc 0.9511 - Dev loss 0.0942, acc 0.9727
# Epoch 4/100 - Train loss 0.1549, acc 0.9547 - Dev loss 0.0907, acc 0.9722
# Epoch 5/100 - Train loss 0.1429, acc 0.9580 - Dev loss 0.1109, acc 0.9725
# Epoch 6/100 - Train loss 0.1408, acc 0.9592 - Dev loss 0.1104, acc 0.9700
# Epoch 7/100 - Train loss 0.1286, acc 0.9635 - Dev loss 0.0916, acc 0.9762
# Epoch 8/100 - Train loss 0.1307, acc 0.9629 - Dev loss 0.1029, acc 0.9722
# Epoch 9/100 - Train loss 0.1273, acc 0.9620 - Dev loss 0.0912, acc 0.9745
# Epoch 10/100 - Train loss 0.1231, acc 0.9647 - Dev loss 0.0972, acc 0.9718
# Epoch 11/100 - Train loss 0.1074, acc 0.9684 - Dev loss 0.1005, acc 0.9747
# Epoch 12/100 - Train loss 0.1059, acc 0.9698 - Dev loss 0.0940, acc 0.9752
# Epoch 13/100 - Train loss 0.1137, acc 0.9673 - Dev loss 0.1025, acc 0.9708
# Epoch 14/100 - Train loss 0.1086, acc 0.9687 - Dev loss 0.1059, acc 0.9770
# Epoch 15/100 - Train loss 0.1041, acc 0.9701 - Dev loss 0.1112, acc 0.9758
# Epoch 16/100 - Train loss 0.1009, acc 0.9699 - Dev loss 0.1163, acc 0.9717
# Epoch 17/100 - Train loss 0.1001, acc 0.9707 - Dev loss 0.1007, acc 0.9777
# Epoch 18/100 - Train loss 0.1009, acc 0.9704 - Dev loss 0.1079, acc 0.9745
# Epoch 19/100 - Train loss 0.0949, acc 0.9722 - Dev loss 0.1192, acc 0.9747
# Epoch 20/100 - Train loss 0.0998, acc 0.9710 - Dev loss 0.1091, acc 0.9735
# Epoch 21/100 - Train loss 0.0840, acc 0.9757 - Dev loss 0.1029, acc 0.9750
# Epoch 22/100 - Train loss 0.0811, acc 0.9756 - Dev loss 0.1108, acc 0.9767
# Epoch 23/100 - Train loss 0.0855, acc 0.9747 - Dev loss 0.1060, acc 0.9762
# Epoch 24/100 - Train loss 0.0831, acc 0.9754 - Dev loss 0.1098, acc 0.9768
# Epoch 25/100 - Train loss 0.0845, acc 0.9754 - Dev loss 0.1238, acc 0.9747
# Early stopping at epoch 25 (no dev-loss improvement for 20 epochs; best epoch was 4, dev loss 0.0907)

# %%
tr_losses_05, tr_accs_05, dev_losses_05, dev_accs_05 = train_model(
    model=model_05,
    train_loader=train_loader,
    dev_loader=dev_loader,
    num_epochs=config.num_epochs,
    lr=config.lr,
    device=device,
    patience=20,
)
# Out:
# Epoch 1/100 - Train loss 1.0964, acc 0.6595 - Dev loss 0.3580, acc 0.9020
# Epoch 2/100 - Train loss 0.8689, acc 0.7305 - Dev loss 0.2495, acc 0.9263
# Epoch 3/100 - Train loss 0.8027, acc 0.7536 - Dev loss 0.2452, acc 0.9250
# Epoch 4/100 - Train loss 0.7561, acc 0.7629 - Dev loss 0.2464, acc 0.9323
# Epoch 5/100 - Train loss 0.8028, acc 0.7504 - Dev loss 0.2719, acc 0.9398
# Epoch 6/100 - Train loss 0.8121, acc 0.7431 - Dev loss 0.2919, acc 0.9227
# Epoch 7/100 - Train loss 0.7662, acc 0.7575 - Dev loss 0.1853, acc 0.9483
# Epoch 8/100 - Train loss 0.7652, acc 0.7628 - Dev loss 0.2219, acc 0.9365
# Epoch 9/100 - Train loss 0.7790, acc 0.7562 - Dev loss 0.3089, acc 0.9140
# Epoch 10/100 - Train loss 0.7394, acc 0.7694 - Dev loss 0.1962, acc 0.9428
# Epoch 11/100 - Train loss 0.7678, acc 0.7592 - Dev loss 0.1819, acc 0.9438
# Epoch 12/100 - Train loss 0.7387, acc 0.7694 - Dev loss 0.1511, acc 0.9533
# Epoch 13/100 - Train loss 0.7031, acc 0.7841 - Dev loss 0.2400, acc 0.9293
# Epoch 14/100 - Train loss 0.7338, acc 0.7734 - Dev loss 0.1903, acc 0.9428
# Epoch 15/100 - Train loss 0.6933, acc 0.7844 - Dev loss 0.1509, acc 0.9540
# Epoch 16/100 - Train loss 0.6959, acc 0.7827 - Dev loss 0.1473, acc 0.9562
# Epoch 17/100 - Train loss 0.7025, acc 0.7833 - Dev loss 0.2097, acc 0.9333
# Epoch 18/100 - Train loss 0.7221, acc 0.7791 - Dev loss 0.1619, acc 0.9502
# Epoch 19/100 - Train loss 0.7036, acc 0.7833 - Dev loss 0.2389, acc 0.9317
# Epoch 20/100 - Train loss 0.6196, acc 0.8241 - Dev loss 0.3387, acc 0.9068
# Epoch 21/100 - Train loss 0.5507, acc 0.8399 - Dev loss 0.1840, acc 0.9603
# Epoch 22/100 - Train loss 0.5863, acc 0.8302 - Dev loss 0.2170, acc 0.9377
# Epoch 23/100 - Train loss 0.5533, acc 0.8370 - Dev loss 0.1897, acc 0.9448
# Epoch 24/100 - Train loss 0.5697, acc 0.8345 - Dev loss 0.1567, acc 0.9555
# Epoch 25/100 - Train loss 0.5694, acc 0.8358 - Dev loss 0.2440, acc 0.9350
# Epoch 26/100 - Train loss 0.5380, acc 0.8437 - Dev loss 0.1567, acc 0.9533
# Epoch 27/100 - Train loss 0.5549, acc 0.8381 - Dev loss 0.1644, acc 0.9562
# Epoch 28/100 - Train loss 0.5720, acc 0.8346 - Dev loss 0.2238, acc 0.9353
# Epoch 29/100 - Train loss 0.5773, acc 0.8327 - Dev loss 0.1536, acc 0.9520
# Epoch 30/100 - Train loss 0.5548, acc 0.8376 - Dev loss 0.1957, acc 0.9443
# Epoch 31/100 - Train loss 0.5162, acc 0.8475 - Dev loss 0.1464, acc 0.9580
# Epoch 32/100 - Train loss 0.5111, acc 0.8504 - Dev loss 0.1536, acc 0.9557
# Epoch 33/100 - Train loss 0.4950, acc 0.8535 - Dev loss 0.1668, acc 0.9572
# Epoch 34/100 - Train loss 0.4796, acc 0.8580 - Dev loss 0.1613, acc 0.9625
# Epoch 35/100 - Train loss 0.4827, acc 0.8571 - Dev loss 0.1603, acc 0.9597
# Epoch 36/100 - Train loss 0.4960, acc 0.8533 - Dev loss 0.1408, acc 0.9633
# Epoch 37/100 - Train loss 0.6268, acc 0.8071 - Dev loss 0.1307, acc 0.9632
# Epoch 38/100 - Train loss 0.5099, acc 0.8506 - Dev loss 0.1451, acc 0.9612
# Epoch 39/100 - Train loss 0.5107, acc 0.8511 - Dev loss 0.1755, acc 0.9475
# Epoch 40/100 - Train loss 0.4974, acc 0.8546 - Dev loss 0.1701, acc 0.9530
# Epoch 41/100 - Train loss 0.4557, acc 0.8623 - Dev loss 0.1347, acc 0.9603
# Epoch 42/100 - Train loss 0.4765, acc 0.8578 - Dev loss 0.1342, acc 0.9590
# Epoch 43/100 - Train loss 0.4690, acc 0.8614 - Dev loss 0.1461, acc 0.9635
# Epoch 44/100 - Train loss 0.4660, acc 0.8634 - Dev loss 0.1306, acc 0.9645
# Epoch 45/100 - Train loss 0.4582, acc 0.8649 - Dev loss 0.1437, acc 0.9657
# Epoch 46/100 - Train loss 0.4529, acc 0.8626 - Dev loss 0.1402, acc 0.9647
# Epoch 47/100 - Train loss 0.4425, acc 0.8683 - Dev loss 0.1537, acc 0.9642
# Epoch 48/100 - Train loss 0.4482, acc 0.8663 - Dev loss 0.1305, acc 0.9660
# Epoch 49/100 - Train loss 0.4577, acc 0.8642 - Dev loss 0.1416, acc 0.9640
# Epoch 50/100 - Train loss 0.4550, acc 0.8645 - Dev loss 0.1491, acc 0.9642
# Epoch 51/100 - Train loss 0.4359, acc 0.8682 - Dev loss 0.1259, acc 0.9643
# Epoch 52/100 - Train loss 0.4451, acc 0.8672 - Dev loss 0.1454, acc 0.9585
# Epoch 53/100 - Train loss 0.4492, acc 0.8620 - Dev loss 0.1678, acc 0.9573
# Epoch 54/100 - Train loss 0.4189, acc 0.8722 - Dev loss 0.1370, acc 0.9603
# Epoch 55/100 - Train loss 0.4265, acc 0.8712 - Dev loss 0.1262, acc 0.9622
# Epoch 56/100 - Train loss 0.4154, acc 0.8731 - Dev loss 0.1382, acc 0.9703
# Epoch 57/100 - Train loss 0.4269, acc 0.8713 - Dev loss 0.1257, acc 0.9685
# Epoch 58/100 - Train loss 0.4128, acc 0.8734 - Dev loss 0.1331, acc 0.9608
# Epoch 59/100 - Train loss 0.4228, acc 0.8726 - Dev loss 0.1351, acc 0.9670
# Epoch 60/100 - Train loss 0.4378, acc 0.8679 - Dev loss 0.1413, acc 0.9663
# Epoch 61/100 - Train loss 0.4036, acc 0.8758 - Dev loss 0.1311, acc 0.9662
# Epoch 62/100 - Train loss 0.4317, acc 0.8689 - Dev loss 0.1556, acc 0.9603
# Epoch 63/100 - Train loss 0.4143, acc 0.8716 - Dev loss 0.1265, acc 0.9677
# Epoch 64/100 - Train loss 0.4115, acc 0.8738 - Dev loss 0.1383, acc 0.9687
# Epoch 65/100 - Train loss 0.3891, acc 0.8790 - Dev loss 0.1367, acc 0.9657
# Epoch 66/100 - Train loss 0.4082, acc 0.8752 - Dev loss 0.1244, acc 0.9668
# Epoch 67/100 - Train loss 0.3899, acc 0.8781 - Dev loss 0.1434, acc 0.9648
# Epoch 68/100 - Train loss 0.3771, acc 0.8831 - Dev loss 0.1251, acc 0.9697
# Epoch 69/100 - Train loss 0.3876, acc 0.8806 - Dev loss 0.1450, acc 0.9608
# Epoch 70/100 - Train loss 0.3893, acc 0.8780 - Dev loss 0.1388, acc 0.9678
# Epoch 71/100 - Train loss 0.3574, acc 0.8869 - Dev loss 0.1409, acc 0.9622
# Epoch 72/100 - Train loss 0.3685, acc 0.8849 - Dev loss 0.1455, acc 0.9742
# Epoch 73/100 - Train loss 0.3742, acc 0.8843 - Dev loss 0.1317, acc 0.9680
# Epoch 74/100 - Train loss 0.3822, acc 0.8823 - Dev loss 0.1384, acc 0.9648
# Epoch 75/100 - Train loss 0.3687, acc 0.8847 - Dev loss 0.1248, acc 0.9703
# Epoch 76/100 - Train loss 0.3583, acc 0.8850 - Dev loss 0.1203, acc 0.9718
# Epoch 77/100 - Train loss 0.3678, acc 0.8852 - Dev loss 0.1308, acc 0.9682
# Epoch 78/100 - Train loss 0.3590, acc 0.8884 - Dev loss 0.1348, acc 0.9703
# Epoch 79/100 - Train loss 0.3660, acc 0.8838 - Dev loss 0.1427, acc 0.9713
# Epoch 80/100 - Train loss 0.3784, acc 0.8836 - Dev loss 0.1424, acc 0.9625
# Epoch 81/100 - Train loss 0.3972, acc 0.8748 - Dev loss 0.1200, acc 0.9678
# Epoch 82/100 - Train loss 0.3608, acc 0.8849 - Dev loss 0.1405, acc 0.9715
# Epoch 83/100 - Train loss 0.3483, acc 0.8879 - Dev loss 0.1363, acc 0.9735
# Epoch 84/100 - Train loss 0.3529, acc 0.8880 - Dev loss 0.1196, acc 0.9728
# Epoch 85/100 - Train loss 0.3507, acc 0.8892 - Dev loss 0.1305, acc 0.9720
# Epoch 86/100 - Train loss 0.3488, acc 0.8901 - Dev loss 0.1333, acc 0.9710
# Epoch 87/100 - Train loss 0.3432, acc 0.8900 - Dev loss 0.1182, acc 0.9740
# Epoch 88/100 - Train loss 0.3612, acc 0.8872 - Dev loss 0.1441, acc 0.9732
# Epoch 89/100 - Train loss 0.3486, acc 0.8890 - Dev loss 0.1215, acc 0.9735
# Epoch 90/100 - Train loss 0.3397, acc 0.8921 - Dev loss 0.1250, acc 0.9707
# Epoch 91/100 - Train loss 0.3409, acc 0.8906 - Dev loss 0.1311, acc 0.9717
# Epoch 92/100 - Train loss 0.3317, acc 0.8936 - Dev loss 0.1587, acc 0.9725
# Epoch 93/100 - Train loss 0.3323, acc 0.8939 - Dev loss 0.1456, acc 0.9697
# Epoch 94/100 - Train loss 0.3348, acc 0.8921 - Dev loss 0.1217, acc 0.9725
# Epoch 95/100 - Train loss 0.3295, acc 0.8945 - Dev loss 0.1399, acc 0.9708
# Epoch 96/100 - Train loss 0.3328, acc 0.8927 - Dev loss 0.1407, acc 0.9732
# Epoch 97/100 - Train loss 0.3335, acc 0.8918 - Dev loss 0.1318, acc 0.9725
# Epoch 98/100 - Train loss 0.3303, acc 0.8940 - Dev loss 0.1450, acc 0.9708
# Epoch 99/100 - Train loss 0.3372, acc 0.8916 - Dev loss 0.1333, acc 0.9712
# Epoch 100/100 - Train loss 0.3253, acc 0.8960 - Dev loss 0.1307, acc 0.9735

# %%
tr_losses_075, tr_accs_075, dev_losses_075, dev_accs_075 = train_model(
    model=model_075,
    train_loader=train_loader,
    dev_loader=dev_loader,
    num_epochs=config.num_epochs,
    lr=config.lr,
    device=device,
    patience=20,
)
# Out:
# Epoch 1/100 - Train loss 2.2000, acc 0.1834 - Dev loss 2.3032, acc 0.1123
# Epoch 2/100 - Train loss 2.3037, acc 0.1064 - Dev loss 2.3032, acc 0.1123
# Epoch 3/100 - Train loss 2.2587, acc 0.1371 - Dev loss 2.3027, acc 0.1123
# Epoch 4/100 - Train loss 2.3035, acc 0.1066 - Dev loss 2.3025, acc 0.1045
# Epoch 5/100 - Train loss 2.2751, acc 0.1243 - Dev loss 2.2538, acc 0.2090
# Epoch 6/100 - Train loss 2.2685, acc 0.1306 - Dev loss 2.3020, acc 0.1123
# Epoch 7/100 - Train loss 2.3023, acc 0.1082 - Dev loss 2.3050, acc 0.1123
# Epoch 8/100 - Train loss 2.3036, acc 0.1076 - Dev loss 2.3024, acc 0.1123
# Epoch 9/100 - Train loss 2.3036, acc 0.1065 - Dev loss 2.3031, acc 0.0987
# Epoch 10/100 - Train loss 2.3034, acc 0.1060 - Dev loss 2.3029, acc 0.1045
# Epoch 11/100 - Train loss 2.3031, acc 0.1085 - Dev loss 2.3019, acc 0.1123
# Epoch 12/100 - Train loss 2.3029, acc 0.1073 - Dev loss 2.3050, acc 0.1123
# Epoch 13/100 - Train loss 2.3034, acc 0.1081 - Dev loss 2.3030, acc 0.1123
# Epoch 14/100 - Train loss 2.3033, acc 0.1066 - Dev loss 2.3023, acc 0.1123
# Epoch 15/100 - Train loss 2.3032, acc 0.1085 - Dev loss 2.3022, acc 0.1123
# Epoch 16/100 - Train loss 2.3036, acc 0.1091 - Dev loss 2.3030, acc 0.1022
# Epoch 17/100 - Train loss 2.3034, acc 0.1090 - Dev loss 2.3023, acc 0.0975
# Epoch 18/100 - Train loss 2.3033, acc 0.1087 - Dev loss 2.3053, acc 0.0987
# Epoch 19/100 - Train loss 2.3031, acc 0.1081 - Dev loss 2.3038, acc 0.1045
# Epoch 20/100 - Train loss 2.3034, acc 0.1075 - Dev loss 2.3019, acc 0.1123
# Epoch 21/100 - Train loss 2.3030, acc 0.1065 - Dev loss 2.3027, acc 0.1123
# Epoch 22/100 - Train loss 2.3031, acc 0.1082 - Dev loss 2.3036, acc 0.1022
# Epoch 23/100 - Train loss 2.3030, acc 0.1092 - Dev loss 2.3020, acc 0.1123
# Epoch 24/100 - Train loss 2.3032, acc 0.1089 - Dev loss 2.3021, acc 0.1123
# Epoch 25/100 - Train loss 2.3029, acc 0.1076 - Dev loss 2.3030, acc 0.1045
# Epoch 26/100 - Train loss 2.3029, acc 0.1099 - Dev loss 2.3045, acc 0.1123
# Early stopping at epoch 26 (no dev-loss improvement for 20 epochs; best epoch was 5, dev loss 2.2538)

# %% [markdown]
# ## 6. Plot learning curves
#
# We visualize loss and accuracy for both training and dev sets
# to see whether the model is overfitting or underfitting.

# %%
print("DROPOUT RATE 0.25", device)
plot_learning_curves(tr_losses_025, tr_accs_025, dev_losses_025, dev_accs_025)
print("DROPOUT RATE 0.5", device)
plot_learning_curves(tr_losses_05, tr_accs_05, dev_losses_05, dev_accs_05)
print("DROPOUT RATE 0.75", device)
plot_learning_curves(tr_losses_075, tr_accs_075, dev_losses_075, dev_accs_075)
# Out:
# DROPOUT RATE 0.25 mps
# DROPOUT RATE 0.5 mps
# DROPOUT RATE 0.75 mps

# %% [markdown]
# # Confusion matrix
# Display a confusion matrix and a classification report showing how the classification looks on the development set. The classification report gives accuracy, as requested in the assignment.

# %%
print("DROPOUT RATE 0.25", device)
evaluate_and_report(model_025, test_loader)
print("DROPOUT RATE 0.5", device)
evaluate_and_report(model_05, test_loader)
print("DROPOUT RATE 0.75", device)
evaluate_and_report(model_075, test_loader)
# Out:
# DROPOUT RATE 0.25 mps
#
# CLASSIFICATION REPORT
#
#               precision    recall  f1-score   support
#
#            0    0.98173   0.98673   0.98422       980
#            1    0.98592   0.98678   0.98635      1135
#            2    0.97300   0.97771   0.97535      1032
#            3    0.97900   0.96931   0.97413      1010
#            4    0.98545   0.96538   0.97531       982
#            5    0.96571   0.97870   0.97216       892
#            6    0.98119   0.98017   0.98068       958
#            7    0.97366   0.97082   0.97224      1028
#            8    0.96936   0.97433   0.97184       974
#            9    0.96453   0.97027   0.96739      1009
#
#     accuracy                        0.97610     10000
#    macro avg    0.97595   0.97602   0.97597     10000
# weighted avg    0.97614   0.97610   0.97610     10000
# DROPOUT RATE 0.5 mps
#
# CLASSIFICATION REPORT
#
#               precision    recall  f1-score   support
#
#            0    0.96803   0.98878   0.97829       980
#            1    0.98589   0.98502   0.98546      1135
#            2    0.97154   0.95930   0.96538      1032
#            3    0.97070   0.98416   0.97738      1010
#            4    0.97245   0.97047   0.97146       982
#            5    0.97200   0.97309   0.97255       892
#            6    0.97899   0.97286   0.97592       958
#            7    0.96508   0.96790   0.96649      1028
#            8    0.96498   0.96201   0.96350       974
#            9    0.96583   0.95243   0.95908      1009
#
#     accuracy                        0.97170     10000
#    macro avg    0.97155   0.97160   0.97155     10000
# weighted avg    0.97171   0.97170   0.97168     10000
# DROPOUT RATE 0.75 mps
#
# CLASSIFICATION REPORT
#
#               precision    recall  f1-score   support
#
#            0    0.00000   0.00000   0.00000       980
#            1    0.11350   1.00000   0.20386      1135
#            2    0.00000   0.00000   0.00000      1032
#            3    0.00000   0.00000   0.00000      1010
#            4    0.00000   0.00000   0.00000       982
#            5    0.00000   0.00000   0.00000       892
#            6    0.00000   0.00000   0.00000       958
#            7    0.00000   0.00000   0.00000      1028
#            8    0.00000   0.00000   0.00000       974
#            9    0.00000   0.00000   0.00000      1009
#
#     accuracy                        0.11350     10000
#    macro avg    0.01135   0.10000   0.02039     10000
# weighted avg    0.01288   0.11350   0.02314     10000
# /Users/nicholasmccracken/Courses/SEM07_FA2026/NeuralNets_5526/mccracken.161/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/nicholasmccracken/Courses/SEM07_FA2026/NeuralNets_5526/mccracken.161/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/nicholasmccracken/Courses/SEM07_FA2026/NeuralNets_5526/mccracken.161/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
print("DROPOUT RATE 0.25", device)
visualize_kernels(model_025, "conv1", num_kernels=6)
visualize_kernels(model_025, "conv2", num_kernels=10)
print("DROPOUT RATE 0.5", device)
visualize_kernels(model_05, "conv1", num_kernels=6)
visualize_kernels(model_05, "conv2", num_kernels=10)
print("DROPOUT RATE 0.75", device)
visualize_kernels(model_075, "conv1", num_kernels=6)
visualize_kernels(model_075, "conv2", num_kernels=10)
# Out:
# DROPOUT RATE 0.25 mps
# DROPOUT RATE 0.5 mps
# DROPOUT RATE 0.75 mps

# %% [markdown]
# ## Discussion of Baseline CNN Overfitting / Underfitting
#
# The 0.25-dropout model performs closest to the baseline CNN: the training and dev curves are relatively smooth with some minor fluctations, accuracy lands slightly higher than baseline, and the confusion matrix shows balanced performance across all digits. Kernels still resemble meaningful edges, indicating the network is stable. Overall, 0.25 dropout reduces mild baseline overfitting while preserving strong convergence.
#
# The 0.5-dropout model regularizes much more aggressively, which leads a to noticeably lower train accuracy and slower convergence. The dev accuracy remains decent but no longer matches baseline performance, and some kernels are noisier now. Compared to baseline, this model actually undefits. Yes, it avoids overfitting completely, but this comes at the cost of overall accuracy via underfitting.
#
# The 0.75-dropout model collapses entirely. Training fails to progress, accuracy is basically just chance, confusion matrix shows almost all predictions mapped to one class, and the kernels appear unstructured. At this level, dropout destroys the network’s ability to learn features the baseline captured easily. This represents extreme underfitting.
#
# Overall, dropout helps the overfitting issue of the baseline CNN, but only at small levels: 0.25 improves generalization vs. baseline, 0.5 starts to weaken the CNN, and 0.75 is just plain destructive.
